# %%
import numpy as np
import pandas as pd

# %%
FILE_PATH = 'banknote_net.feather'
df = pd.read_feather(FILE_PATH)
df
# Out:
#             v_0       v_1       v_2       v_3       v_4       v_5       v_6  \
# 0      0.423395  0.327657  2.568988  3.166228  4.801421  5.531792  2.458083
# 1      1.158823  1.669602  3.638447  2.823524  4.839890  2.777757  0.753350
# 2      0.000000  0.958235  4.706119  1.688242  3.312702  4.516483  0.000000
# 3      0.920511  1.820294  3.939334  3.206829  6.253655  0.942557  2.952453
# 4      0.331918  0.000000  3.330771  3.023437  4.369099  5.177336  1.499362
# ...         ...       ...       ...       ...       ...       ...       ...
# 24821  0.000000  3.076672  1.849998  0.635259  6.472688  0.000000  2.214436
# 24822  0.000000  4.471694  2.024621  0.194067  6.469818  0.000000  1.756854
# 24823  0.000000  3.726544  1.780134  1.752426  3.299378  0.422422  0.527200
# 24824  0.250622  2.615436  1.329533  0.741571  5.485542  0.000000  2.267793
# 24825  0.000000  4.508471  1.943896  0.000000  5.995752  0.000000  4.632102
#
# ...

# %%
# Out:
# 56
